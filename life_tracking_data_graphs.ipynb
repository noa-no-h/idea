# %% [markdown]
# <a href="https://colab.research.google.com/github/noa-no-h/noa.github.io/blob/master/life_tracking_data_graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaleido
# !pip install plotly>=4.0.0
# !wget https://github.com/plotly/orca/releases/download/v1.2.1/orca-1.2.1-x86_64.AppImage -O /usr/local/bin/orca
# !chmod +x /usr/local/bin/orca
# !apt-get install xvfb libgtk2.0-0 libgconf-2-4

# %%
import gspread
import pandas as pd
from google.colab import auth
from oauth2client.client import GoogleCredentials
import openpyxl
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
from plotly.subplots import make_subplots

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

ws = gc.open('Life_Tracking').sheet1
rows = ws.get_all_values()
df=pd.DataFrame.from_records(rows)

dfcut1=(df.iloc[1:239:2,3:13])


header1 = dfcut1.iloc[0]
#print(header)
dfcut1 = dfcut1[1:]
#print(dfcut0)
dfcut1.columns = header1
#print(dfcut0)

dfLife=dfcut1.T

headerT1 = dfLife.iloc[0]
#print(headerT)
dfLife = dfLife[1:]
#print(dft)
dfLife.columns = headerT1
#print(df)

dfLife=dfLife.reset_index()
dfLife.set_index(1,inplace=True)



dat=gc.open('Life_Tracking')
data=dat.worksheet("Data_Analysis")
rows1 = data.get_all_values()
data=pd.DataFrame.from_records(rows1)
data=(data.iloc[0:234:2,0:5])


dfStatsLife=data.T
dfStatsLife.set_index(0,inplace=True)
dfStatsLife.columns = dfLife.columns


#make everything floats in both dfs
cols = dfLife.columns
dfLife[cols] = dfLife[cols].apply(pd.to_numeric, errors='coerce')

cols = dfStatsLife.columns
dfStatsLife[cols] = dfStatsLife[cols].apply(pd.to_numeric, errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
#categories
da=gc.open('Life_Tracking')
df2=da.worksheet("Sheet1")
rows1 = df2.get_all_values()
dfCategories=pd.DataFrame.from_records(rows1)
dfCategories=(dfCategories.iloc[1:234:2,0])
dfCategories=(dfCategories.drop([1]))
ListCategories=dfCategories.to_list()

for i in ListCategories:
  if i=='':
    if ListCategories[i-1]=='':
# Out:
# True
# "\nfor i in ListCategories:\n  if i==''\n"

# %%
ws = gc.open('Life_Tracking').sheet1
rows = ws.get_all_values()
df=pd.DataFrame.from_records(rows)

dfcut1=(df.iloc[1:239:2,0:13])
cols = [1,2]
dfcut1.drop(dfcut1.columns[cols],axis=1,inplace=True)

header1 = dfcut1.iloc[0]
#print(header)
dfcut1 = dfcut1[0:]
#print(dfcut0)
dfcut1.columns = header1
#print(dfcut0)

dfLife=dfcut1.T


#exchange the first two columns

#print(dfLife)
#print(dfLife.iloc[0])
#print(dfLife.iloc[1])
b, c = dfLife.iloc[0], dfLife.iloc[1]
temp = dfLife.iloc[0].copy()
#print(dfLife.iloc[0])
#print(dfLife.iloc[1])
dfLife.iloc[0] = c
dfLife.iloc[1] = temp
print(dfLife.iloc[0])
#print(dfLife.iloc[1])
#print(dfLife)
headerT1 = dfLife.iloc[0]
#print(headerT)
dfLife = dfLife[1:]
#print(dft)
dfLife.columns = headerT1
#print(df)
#print(dfLife)

cols=[0]
dfLife.drop(dfLife.columns[cols],axis=1,inplace=True)




#dfLife=dfLife.reset_index()
#dfLife.set_index(1,inplace=True)

dfLife
# Out:
# 1      Short Name
# 3         control
# 5           foods
# 7          future
# 9            past
#           ...
# 225       laundry
# 227         clean
# 229       russian
# 231        french
# 233       english
# Name: category, Length: 117, dtype: object
# category              control foods future past  ... clean   russian french english
# 1                                                ...
# Short Name      Life and Mood                    ...        Language
# March 2021                  9     2     10    3  ...     9      3491   4928
# April 2021                  4     0     10    4  ...     9      3491             70
# May 2021                    7     1     10    3  ...     9      3491
# June 2021                   8     2      8    5  ...     9      3527
# July 2021                   7     5      9    4  ...     7      3661   5200      79
# August 2021                       0              ...
# September 2021                    0              ...
# ...

# %%
dat=gc.open('Life_Tracking')
data=dat.worksheet("Sheet1")
rows1 = data.get_all_values()
dfLables=pd.DataFrame.from_records(rows1)
dfLables=(dfLables.iloc[0:239:2,3:13])


dfLables.set_index(3,inplace=True)
headerT1 = dfLables.iloc[0]
dfLables = dfLables[1:]
dfLables.columns = headerT1


dfLables
# Out:
#     3       4       5       6   ...      9       10      11      12
# 0       202103  202104  202105  ...  202108  202109  202110  202111
# 2                               ...
# 4                               ...
# 6                               ...
# 8                               ...
# ..  ..     ...     ...     ...  ...     ...     ...     ...     ...
# 224                             ...
# 226                             ...
# 228                             ...
# 230                             ...
# 232                             ...
#
# [117 rows x 10 columns]

# %%
#THIS CREATES THE PULL
#the pull is the distance of a data point from the mean (#-mean) in units of standard deviation lengths (so devide by stdev)
"""
dfPull=dfLife

cols = dfPull.columns
for col in cols:
  dfPull[col] = (dfLife[col]- float(dfStatsLife.loc['mean',col]))/float(dfStatsLife.loc['stdev',col])


"""
#THIS CREATES THE FRACMAX

dfFracMax=dfLife

cols = dfFracMax.columns
for col in cols:
  dfFracMax[col] = dfLife[col]/float(dfStatsLife.loc['max value',col])
dfFracMax


fig = go.Figure()

for col in cols:
  fig.add_trace(go.Scatter(x=dfFracMax.index, y=dfFracMax[col],
                    mode='lines+markers',
                    name=col))


fig.show()

#NOTE TO SELF: MAKE LINE OPACITY GO WITH MONTH TO MONTH DERIVATIVE
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="65ecdecb-e7fc-49d1-bcb3-4d544f15ed47" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("65ecdecb-e7fc-49d1-bcb3-4d544f15ed47")) {
#                     Plotly.newPlot(
#                         '65ecdecb-e7fc-49d1-bcb3-4d544f15ed47',
# ...

# %%
import gspread

gc = gspread.service_account(filename='drive/MyDrive/1🎓 Learning/Programming/sheetbook-317322-578678c76bb6.json')

sh = gc.open("Life_Tracking")

print(sh.sheet1.get('A1'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-03114bc4728c> in <module>()
#       1 import gspread
#       2
# ----> 3 gc = gspread.service_account(filename='drive/MyDrive/1🎓 Learning/Programming/sheetbook-317322-578678c76bb6.json')
#       4
#       5 sh = gc.open("Life_Tracking")
#
# AttributeError: module 'gspread' has no attribute 'service_account'

# %%
#https://docs.gspread.org/en/latest/oauth2.html


import gspread

credentials = {
  "type":	"service_account",
  "project_id":	"sheetbook-317322",
  "private_key_id":	"578678c76bb67c21a3efcfcc163ca2805eaebb9a",
  "private_key":	"-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
  "client_email":	"sheetbook-317322@appspot.gserviceaccount.com",
  "client_id":	"109157274619670134481",
  "auth_uri":	"https://accounts.google.com/o/oauth2/auth",
  "token_uri":	"https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url":	"https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url":	"https://www.googleapis.com/robot/v1/metadata/x509/sheetbook-317322%40appspot.gserviceaccount.com"
}

	

gc = gspread.service_account_from_dict(credentials)

sh = gc.open("Life_Tracking")

print(sh.sheet1.get('A1'))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-2c445ffcd2f7>", line 21, in <module>
#     gc = gspread.service_account_from_dict(credentials)
# AttributeError: module 'gspread' has no attribute 'service_account_from_dict'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py", line 1823, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
# !pip install kora -q
from kora import drive
drive.chdir_notebook()
# Out:
#      |████████████████████████████████| 57 kB 4.9 MB/s
#      |████████████████████████████████| 56 kB 4.4 MB/s
# PosixPath('/content/drive/My Drive/Home Updated 2021/1🎓 Learning/Programming/Colab Notebooks')

# %%
# !pwd
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# pwd: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
